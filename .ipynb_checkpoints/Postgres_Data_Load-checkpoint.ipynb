# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from time import time

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
pwd
# Out:
# '/workspaces/SureshZoomCamp_DE'

# %%
df = pd.read_parquet('/workspaces/SureshZoomCamp_DE/2_Docker/yellow_tripdata_2021-01.parquet', engine='pyarrow')

# %%
df.shape
# Out:
# (1369769, 19)

# %%
from sqlalchemy import create_engine
#install psycopg2 for fulfilling the dependency

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df,name ='yellow_taxi_data',con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
parquet_file = pq.ParquetFile('/workspaces/SureshZoomCamp_DE/2_Docker/yellow_tripdata_2021-01.parquet')

# %%
batches = parquet_file.iter_batches(batch_size = 100000)

# %%
type(batches)
# Out:
# _cython_3_0_10.generator

# %%
for batch in batches:
    df = batch.to_pandas()
    print(df.shape)
# Out:
# (100000, 19)
# (100000, 19)
# (100000, 19)
# (100000, 19)
# (100000, 19)
# (100000, 19)
# (100000, 19)
# (100000, 19)
# (100000, 19)
# (100000, 19)
# (100000, 19)
# (100000, 19)
# (100000, 19)
# (69769, 19)

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             6  2021-01-10 17:01:17   2021-01-10 17:01:04              NaN
# 1             2  2021-01-10 17:32:52   2021-01-10 17:50:00              NaN
# 2             2  2021-01-10 17:11:00   2021-01-10 17:59:00              NaN
# 3             2  2021-01-10 17:37:00   2021-01-10 18:02:00              NaN
# 4             6  2021-01-10 17:01:43   2021-01-10 17:01:02              NaN
# ...         ...                  ...                   ...              ...
# 69764         2  2021-01-31 23:03:00   2021-01-31 23:33:00              NaN
# 69765         2  2021-01-31 23:29:00   2021-01-31 23:51:00              NaN
# 69766         2  2021-01-31 23:25:00   2021-01-31 23:38:00              NaN
# 69767         6  2021-01-31 23:01:06   2021-02-01 00:02:03              NaN
# 69768         2  2021-01-31 23:08:29   2021-01-31 23:31:22              NaN
#
# ...

# %%
df.describe()
# Out:
#            VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  69769.000000                       69769                       69769
# mean       2.277587  2021-01-21 01:07:09.286187  2021-01-21 01:29:06.751150
# min        1.000000         2021-01-10 17:00:56         2021-01-10 17:01:02
# 25%        2.000000         2021-01-15 09:32:00         2021-01-15 09:54:00
# 50%        2.000000         2021-01-21 04:10:22         2021-01-21 04:33:00
# 75%        2.000000         2021-01-26 13:57:00         2021-01-26 14:14:48
# max        6.000000         2021-01-31 23:56:00         2021-02-01 00:38:00
# std        1.280051                         NaN                         NaN
#
#        passenger_count  trip_distance  RatecodeID  PULocationID  DOLocationID  \
# count              0.0   69769.000000         0.0  69769.000000  69769.000000
# mean               NaN      30.925027         NaN    151.456463    136.136995
# ...

# %%
df.head(n=0)
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, airport_fee]
# Index: []

# %%
df.head(n=0).to_sql(name='yellow_taxi_data',con=engine,if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='yellow_taxi_data',con=engine,if_exists='append') # applicable for csv

# %%
i = 0

# %%
print(f"inserted another chunk..{i}, took %.3f" % (i-i))
# Out:
# inserted another chunk..0, took 0.000

# %%
batches = (parquet_file.iter_batches(batch_size = 100000))

# %%
for batch in batches:
    i=i+1
    t_start = time()
    df_load = batch.to_pandas()
    df_load.to_sql(name='yellow_taxi_data',con=engine,if_exists='append')
    t_end = time()
    print(f"inserted another chunk..{i}, took %.3f" % (t_end-t_start))
# Out:
# inserted another chunk..1, took 9.446
# inserted another chunk..2, took 9.514
# inserted another chunk..3, took 9.612
# inserted another chunk..4, took 10.121
# inserted another chunk..5, took 9.453
# inserted another chunk..6, took 9.854
# inserted another chunk..7, took 9.826
# inserted another chunk..8, took 9.504
# inserted another chunk..9, took 9.912
# inserted another chunk..10, took 9.458
# inserted another chunk..11, took 9.560
# inserted another chunk..12, took 9.844
# inserted another chunk..13, took 9.421
# inserted another chunk..14, took 6.156
